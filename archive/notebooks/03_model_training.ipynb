# %% [markdown]
# # Notebook 03 — Model Training
#
# Trains three sequence models to predict satellite positions at T+10, T+30, T+60, and T+120 minutes from a 90-minute observation window:
#
# 1. **MLP** — flat baseline (no temporal structure) — ablation control
# 2. **LSTM** — bidirectional LSTM encoder followed by a fully-connected head
# 3. **Transformer** — sinusoidal positional encoding + encoder-only Transformer, FC head
#
# **Input:** `.npy` arrays + `scaler_X.pkl` from Notebook 02
# **Output:** `mlp_orbit.pt`, `lstm_orbit.pt`, `transformer_orbit.pt` saved to `data/collected/` (or `/content/` on Colab)
#
# ---
#
# ### Run 5 Updates (STALE_DAYS = 7 tuning)
#
# **Problem from Run 4:** LSTM diverged badly (val loss 0.2425 → 1.2958 at epoch 10) with STALE_DAYS=7 residuals (10–100x larger).
# **Solution:** Increase LSTM capacity:
# - `HIDDEN: 128 → 256` — larger embeddings for harder task
# - `LSTM_LAYERS: 1 → 2` — enables internal LSTM dropout (PyTorch disables it for single-layer LSTMs) + better expressivity
#
# Expected result: LSTM should train smoothly to epoch 50+ without divergence.
#
# ---
#
# ### Colab GPU tip
# Enable GPU: **Runtime → Change runtime type → T4 GPU**.
# All three models train in under 25 minutes on T4 for a 5-satellite, 180-day dataset.

# %% [markdown]
# ## 0 — Environment Setup

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print('Running on Google Colab')
    import subprocess
    subprocess.run(['pip', 'install', '-q', 'torch', 'plotly'], check=True)
else:
    print('Running locally')

import os, io, zipfile, json, math, pickle, time
from pathlib import Path
from copy import deepcopy

import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

pio.renderers.default = 'plotly_mimetype'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR = Path('/content') if IN_COLAB else Path('../data/collected')
print(f'Device: {DEVICE}')
print(f'PyTorch version: {torch.__version__}')
# Out:
# Running on Google Colab
# Device: cuda
# PyTorch version: 2.11.0+cu128

# %% [markdown]
# ## 1 — Load Data
#
# **Colab:** upload `dataset.zip` from Notebook 02.
# **Local:** arrays are loaded from `data/collected/` automatically.

# %%
if IN_COLAB:
    _needed = ['X_train.npy', 'y_res_train.npy', 'X_val.npy', 'y_res_val.npy',
               'X_test.npy',  'y_res_test.npy',  'scaler_X.pkl', 'scaler_res.pkl',
               'dataset_meta.json']
    _zip_path = DATA_DIR / 'dataset.zip'

    # Check if dataset.zip is already present and extract if needed
    _initial_missing = [f for f in _needed if not (DATA_DIR / f).exists()]
    if _zip_path.exists() and _initial_missing:
        print('Found existing dataset.zip; attempting to extract.')
        try:
            with zipfile.ZipFile(_zip_path, 'r') as zf:
                zf.extractall(DATA_DIR)
            print('Extracted existing dataset.zip.')
            _missing = [f for f in _needed if not (DATA_DIR / f).exists()] # Re-check
        except zipfile.BadZipFile:
            print(f'Warning: dataset.zip at {_zip_path} is corrupted. Please upload a valid one.')
            _missing = _initial_missing # Still missing
    else:
        _missing = _initial_missing # No zip to extract or no initial missing files

    # If files are still missing, prompt for upload
    if _missing:
        from google.colab import files as _colab_files
        print('Upload the dataset.zip from Notebook 02.')
        _uploaded = _colab_files.upload()
        if _uploaded: # Safely process upload if a file was provided
            _zip_bytes = next(iter(_uploaded.values()))
            try:
                with zipfile.ZipFile(io.BytesIO(_zip_bytes)) as zf:
                    zf.extractall(DATA_DIR)
                print('Extracted uploaded dataset.zip.')
                _missing = [f for f in _needed if not (DATA_DIR / f).exists()] # Re-check after upload/extraction
            except zipfile.BadZipFile:
                print('Warning: Uploaded dataset.zip is corrupted. Please upload a valid one.')
                _missing = [f for f in _needed if not (DATA_DIR / f).exists()] # Keep track of missing
            if _missing:
                print(f'Warning: The following files are still missing after processing: {_missing}')
            else:
                print('All needed files are now present after upload and extraction.')
        else:
            print('No file was uploaded by the user. Data loading might fail.')
    elif not _missing:
        print('All needed files are already present.')

# Load features
X_train = np.load(DATA_DIR / 'X_train.npy')
X_val   = np.load(DATA_DIR / 'X_val.npy')
X_test  = np.load(DATA_DIR / 'X_test.npy')

# Load RESIDUAL targets (y_true − y_SGP4_stale), already scaled
y_train = np.load(DATA_DIR / 'y_res_train.npy')
y_val   = np.load(DATA_DIR / 'y_res_val.npy')
y_test  = np.load(DATA_DIR / 'y_res_test.npy')

# ── Drop rows where SGP4 stale was unavailable (residual = NaN) ─────────────
# NaN rows would produce NaN loss → NaN gradients → training collapses.
def valid_mask(y):
    return ~np.isnan(y).any(axis=(1, 2))

train_mask = valid_mask(y_train)
val_mask   = valid_mask(y_val)
test_mask  = valid_mask(y_test)

X_train, y_train = X_train[train_mask], y_train[train_mask]
X_val,   y_val   = X_val[val_mask],     y_val[val_mask]
X_test,  y_test  = X_test[test_mask],   y_test[test_mask]

print(f'After NaN drop — Train: {len(X_train):,}  Val: {len(X_val):,}  Test: {len(X_test):,}')

with open(DATA_DIR / 'dataset_meta.json') as f:
    meta = json.load(f)

N_FEATURES  = X_train.shape[-1]
INPUT_LEN   = X_train.shape[1]
N_HORIZONS  = y_train.shape[1]   # 4
N_TARGETS   = y_train.shape[2]   # 3 (lat, lon, alt)
N_OUT       = N_HORIZONS * N_TARGETS  # 12

print(f'X_train: {X_train.shape}  y_train (residuals): {y_train.shape}')
print(f'Features: {N_FEATURES}  Horizons: {N_HORIZONS}  Targets/horizon: {N_TARGETS}')
print('Training target = SGP4 correction residual (y_true − y_SGP4_stale)')
# Out:
# Found existing dataset.zip; attempting to extract.
# Extracted existing dataset.zip.
# All needed files are already present.
# After NaN drop — Train: 144,613  Val: 30,685  Test: 31,533
# X_train: (144613, 90, 15)  y_train (residuals): (144613, 4, 3)
# Features: 15  Horizons: 4  Targets/horizon: 3
# Training target = SGP4 correction residual (y_true − y_SGP4_stale)

# %% [markdown]
# ## 2 — Hyperparameters & DataLoaders

# %%
HIDDEN        = 256   # increased from 128 — STALE_DAYS=7 has 10-100x larger residuals
LSTM_LAYERS   = 2     # increased from 1 — enables internal LSTM dropout + handles harder task
TF_HEADS      = 4
TF_ENC_LAYERS = 2
TF_FF_DIM     = 256   # matches HIDDEN
DROPOUT       = 0.3   # stronger regularisation
EPOCHS        = 100
BATCH         = 128
LR            = 3e-4  # learning rate unchanged for now
PATIENCE      = 20    # more patience for val to improve

def make_loader(X, y, batch, shuffle):
    Xt = torch.tensor(X, dtype=torch.float32)
    yt = torch.tensor(y.reshape(len(y), -1), dtype=torch.float32)  # flatten to (N, 12)
    return DataLoader(TensorDataset(Xt, yt), batch_size=batch, shuffle=shuffle, pin_memory=True)

train_dl = make_loader(X_train, y_train, BATCH, shuffle=True)
val_dl   = make_loader(X_val,   y_val,   BATCH, shuffle=False)
test_dl  = make_loader(X_test,  y_test,  BATCH, shuffle=False)
print(f'Train batches: {len(train_dl)}  Val batches: {len(val_dl)}  Test batches: {len(test_dl)}')
# Out:
# Train batches: 1130  Val batches: 240  Test batches: 247

# %% [markdown]
# ## 2b — Optuna Hyperparameter Tuning (Optional)
#
# **Skip this section if you want to use manual hyperparameters from cell 7 above.**
#
# Use Optuna + ASHA pruner to automatically find best hyperparameters. This searches over:
# - `HIDDEN`: 128–512
# - `LSTM_LAYERS`: 1–3
# - `DROPOUT`: 0.1–0.5
# - `LR`: 1e-5 to 1e-3 (log scale)
# - `WEIGHT_DECAY`: 1e-5 to 1e-2 (log scale)
#
# **Expects ~30–50 trials, 2–4 hours on GPU.** Each bad trial is pruned at epoch 20 to save compute.

# %%
if IN_COLAB:
    import subprocess
    subprocess.run(['pip', 'install', '-q', 'optuna'], check=True)

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.samplers import TPESampler
import logging
optuna.logging.set_verbosity(optuna.logging.WARNING)

print(f'Optuna version: {optuna.__version__}')

# ─────────────────────────────────────────────────────────────────────────────
# Define model classes here (before objective functions reference them)
# ─────────────────────────────────────────────────────────────────────────────

class MLPOrbit(nn.Module):
    """Flat MLP — no temporal structure. Ablation baseline."""
    def __init__(self, input_len, n_features, hidden, n_out, dropout):
        super().__init__()
        in_dim = input_len * n_features
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden * 2),
            nn.LayerNorm(hidden * 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden * 2, hidden),
            nn.LayerNorm(hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, n_out),
        )

    def forward(self, x):
        return self.net(x.flatten(start_dim=1))


class LSTMOrbit(nn.Module):
    def __init__(self, n_features, hidden, lstm_layers, n_out, dropout):
        super().__init__()
        self.lstm = nn.LSTM(n_features, hidden, lstm_layers,
                            batch_first=True, bidirectional=True,
                            dropout=dropout if lstm_layers > 1 else 0)
        self.hidden_dropout = nn.Dropout(dropout)
        fc_in = hidden * 2
        self.head = nn.Sequential(
            nn.LayerNorm(fc_in),
            nn.Linear(fc_in, fc_in // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(fc_in // 2, n_out),
        )

    def forward(self, x):
        _, (h, _) = self.lstm(x)
        return self.head(self.hidden_dropout(torch.cat([h[-2], h[-1]], dim=-1)))


class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=500, dropout=0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(max_len).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div[:d_model // 2])
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return self.dropout(x + self.pe[:, :x.size(1)])


class TransformerOrbit(nn.Module):
    def __init__(self, n_features, d_model, nhead, num_encoder_layers, ff_dim, n_out, dropout):
        super().__init__()
        self.input_proj = nn.Linear(n_features, d_model)
        self.pos_enc    = PositionalEncoding(d_model, dropout=dropout)
        enc_layer = nn.TransformerEncoderLayer(d_model, nhead, ff_dim,
                                               dropout=dropout, batch_first=True,
                                               norm_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_encoder_layers)
        self.head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, n_out),
        )

    def forward(self, x):
        x = self.pos_enc(self.input_proj(x))
        x = self.encoder(x)
        ctx = x.mean(dim=1)
        return self.head(ctx)

print('Model classes defined. Ready to run hyperparameter search.')
# Out:
# Optuna version: 4.9.0
# Model classes defined. Ready to run hyperparameter search.

# %%
def objective_mlp(trial):
    """Optuna objective for MLP model."""
    hidden = trial.suggest_int('mlp_hidden', 128, 512, step=64)
    dropout = trial.suggest_float('mlp_dropout', 0.1, 0.5)
    lr = trial.suggest_float('mlp_lr', 1e-5, 1e-3, log=True)
    weight_decay = trial.suggest_float('mlp_weight_decay', 1e-5, 1e-2, log=True)

    model = MLPOrbit(INPUT_LEN, N_FEATURES, hidden, N_OUT, dropout).to(DEVICE)
    criterion = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=lr/100)

    best_val = float('inf')
    best_state = None
    wait = 0
    patience = PATIENCE

    for epoch in range(1, EPOCHS + 1):
        # Train
        model.train()
        running = 0.0
        for Xb, yb in train_dl:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(Xb), yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            running += loss.item() * len(Xb)
        scheduler.step()
        train_loss = running / len(train_dl.dataset)

        # Validate
        model.eval()
        running = 0.0
        with torch.no_grad():
            for Xb, yb in val_dl:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                running += criterion(model(Xb), yb).item() * len(Xb)
        val_loss = running / len(val_dl.dataset)

        if val_loss < best_val:
            best_val = val_loss
            best_state = deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1

        # Pruning: report intermediate value, check if trial should be pruned
        trial.report(val_loss, epoch)
        if trial.should_prune():
            raise optuna.TrialPruned()

        if wait >= patience:
            break

    return best_val if best_state is not None else float('inf')


def objective_lstm(trial):
    """Optuna objective for LSTM model."""
    hidden = trial.suggest_int('lstm_hidden', 128, 512, step=64)
    lstm_layers = trial.suggest_int('lstm_layers', 1, 3)
    dropout = trial.suggest_float('lstm_dropout', 0.1, 0.5)
    lr = trial.suggest_float('lstm_lr', 1e-5, 1e-3, log=True)
    weight_decay = trial.suggest_float('lstm_weight_decay', 1e-5, 1e-2, log=True)

    model = LSTMOrbit(N_FEATURES, hidden, lstm_layers, N_OUT, dropout).to(DEVICE)
    criterion = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=lr/100)

    best_val = float('inf')
    best_state = None
    wait = 0
    patience = PATIENCE

    for epoch in range(1, EPOCHS + 1):
        # Train
        model.train()
        running = 0.0
        for Xb, yb in train_dl:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(Xb), yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            running += loss.item() * len(Xb)
        scheduler.step()
        train_loss = running / len(train_dl.dataset)

        # Validate
        model.eval()
        running = 0.0
        with torch.no_grad():
            for Xb, yb in val_dl:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                running += criterion(model(Xb), yb).item() * len(Xb)
        val_loss = running / len(val_dl.dataset)

        if val_loss < best_val:
            best_val = val_loss
            best_state = deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1

        trial.report(val_loss, epoch)
        if trial.should_prune():
            raise optuna.TrialPruned()

        if wait >= patience:
            break

    return best_val if best_state is not None else float('inf')


def objective_transformer(trial):
    """Optuna objective for Transformer model."""
    hidden = trial.suggest_int('tf_hidden', 128, 512, step=64)
    nhead = trial.suggest_categorical('tf_nhead', [2, 4, 8])
    ff_dim = trial.suggest_int('tf_ff_dim', 256, 1024, step=128)
    dropout = trial.suggest_float('tf_dropout', 0.1, 0.5)
    lr = trial.suggest_float('tf_lr', 1e-5, 1e-3, log=True)
    weight_decay = trial.suggest_float('tf_weight_decay', 1e-5, 1e-2, log=True)

    model = TransformerOrbit(N_FEATURES, hidden, nhead, TF_ENC_LAYERS, ff_dim, N_OUT, dropout).to(DEVICE)
    criterion = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=lr/100)

    best_val = float('inf')
    best_state = None
    wait = 0
    patience = PATIENCE

    for epoch in range(1, EPOCHS + 1):
        # Train
        model.train()
        running = 0.0
        for Xb, yb in train_dl:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(Xb), yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            running += loss.item() * len(Xb)
        scheduler.step()
        train_loss = running / len(train_dl.dataset)

        # Validate
        model.eval()
        running = 0.0
        with torch.no_grad():
            for Xb, yb in val_dl:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                running += criterion(model(Xb), yb).item() * len(Xb)
        val_loss = running / len(val_dl.dataset)

        if val_loss < best_val:
            best_val = val_loss
            best_state = deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1

        trial.report(val_loss, epoch)
        if trial.should_prune():
            raise optuna.TrialPruned()

        if wait >= patience:
            break

    return best_val if best_state is not None else float('inf')

print('Objective functions ready.')
# Out:
# Objective functions ready.

# %%
# ── Configure Optuna search ───────────────────────────────────────────────
N_TRIALS = 30  # increase to 50 for more thorough search
TIMEOUT_SECONDS = 4 * 3600  # 4 hours

sampler = TPESampler(seed=42)
pruner = SuccessiveHalvingPruner(
    min_resource=20,     # min epochs before pruning
    reduction_factor=2,  # each stage uses half the trials
)

# ── Run MLP search ──────────────────────────────────────────────────────────
print('='*60)
print('SEARCHING MLP HYPERPARAMETERS')
print('='*60)
study_mlp = optuna.create_study(sampler=sampler, pruner=pruner, direction='minimize')
study_mlp.optimize(objective_mlp, n_trials=N_TRIALS, timeout=TIMEOUT_SECONDS, n_jobs=-1, show_progress_bar=True)

print(f'\n[MLP] Best trial:')
print(f'  Val loss: {study_mlp.best_value:.6f}')
print(f'  Params: {study_mlp.best_params}')
# Out:
# ...
# SEARCHING MLP HYPERPARAMETERS
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [MLP] Best trial:
#   Val loss: 0.100872
#   Params: {'mlp_hidden': 192, 'mlp_dropout': 0.16016267502839449, 'mlp_lr': 5.44867000738456e-05, 'mlp_weight_decay': 1.2973613997752668e-05}

# %%
# ── Run LSTM search ─────────────────────────────────────────────────────────
print('\n' + '='*60)
print('SEARCHING LSTM HYPERPARAMETERS')
print('='*60)
study_lstm = optuna.create_study(sampler=sampler, pruner=pruner, direction='minimize')
study_lstm.optimize(objective_lstm, n_trials=N_TRIALS, timeout=TIMEOUT_SECONDS, n_jobs=-1, show_progress_bar=True)

print(f'\n[LSTM] Best trial:')
print(f'  Val loss: {study_lstm.best_value:.6f}')
print(f'  Params: {study_lstm.best_params}')
# Out:
# ...
# SEARCHING LSTM HYPERPARAMETERS
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# ── Run Transformer search ──────────────────────────────────────────────────
print('\n' + '='*60)
print('SEARCHING TRANSFORMER HYPERPARAMETERS')
print('='*60)
study_tf = optuna.create_study(sampler=sampler, pruner=pruner, direction='minimize')
study_tf.optimize(objective_transformer, n_trials=N_TRIALS, timeout=TIMEOUT_SECONDS, n_jobs=-1, show_progress_bar=True)

print(f'\n[Transformer] Best trial:')
print(f'  Val loss: {study_tf.best_value:.6f}')
print(f'  Params: {study_tf.best_params}')

# %% [markdown]
# ### Save Hyperparameters to Google Drive (for persistence)
#
# To ensure your search results are saved even if your Colab session disconnects, we'll mount your Google Drive and save the `best_hparams.json` file there. This way, you won't lose your findings if your laptop hibernates or your session ends.

# %%
# ── Compile results ────────────────────────────────────────────────────────
best_config = {
    'mlp': {
        'val_loss': study_mlp.best_value,
        'params': study_mlp.best_params,
    },
    'lstm': {
        'val_loss': study_lstm.best_value,
        'params': study_lstm.best_params,
    },
    'transformer': {
        'val_loss': study_tf.best_value,
        'params': study_tf.best_params,
    },
}

# ── Display summary table ───────────────────────────────────────────────────
import pandas as pd
summary = pd.DataFrame([
    {'Model': 'MLP', 'Best Val Loss': f"{study_mlp.best_value:.6f}",
     'Best Trial': study_mlp.best_trial.number},
    {'Model': 'LSTM', 'Best Val Loss': f"{study_lstm.best_value:.6f}",
     'Best Trial': study_lstm.best_trial.number},
    {'Model': 'Transformer', 'Best Val Loss': f"{study_tf.best_value:.6f}",
     'Best Trial': study_tf.best_trial.number},
])
print('\n' + '='*60)
print('HYPERPARAMETER SEARCH SUMMARY')
print('='*60)
print(summary.to_string(index=False))

# ── Save to JSON for Colab runs ─────────────────────────────────────────────
config_path = DATA_DIR / 'best_hparams.json'
with open(config_path, 'w') as f:
    # Clean up param names for readability
    clean_config = {}
    for model_name, data in best_config.items():
        clean_params = {k.split('_', 1)[-1]: v for k, v in data['params'].items()}
        clean_config[model_name] = {'val_loss': data['val_loss'], 'params': clean_params}
    json.dump(clean_config, f, indent=2)

print(f'\nSaved: {config_path.resolve()}')
print('\nTo use these hyperparameters in Colab:')
print('1. Download best_hparams.json from output')
print('2. Edit NB03 cell 7 to manually set HIDDEN, LSTM_LAYERS, etc. from best_config')
print('   OR load hparams automatically (see next cell)')

# %%
if IN_COLAB:
    from google.colab import drive
    # This will prompt you to authorize Colab to access your Google Drive
    drive.mount('/content/gdrive')
    DRIVE_DIR = Path('/content/gdrive/My Drive/Colab Notebooks/Orbital_Forecast') # Adjust this path as needed
    DRIVE_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Google Drive mounted to {DRIVE_DIR}')
else:
    DRIVE_DIR = DATA_DIR # Use local data directory if not in Colab

# Update the path where best_hparams.json will be saved
CONFIG_SAVE_PATH = DRIVE_DIR / 'best_hparams.json'
print(f'Hyperparameters will be saved to: {CONFIG_SAVE_PATH}')

# %%
# ── Save to JSON for persistent storage (Google Drive in Colab) ─────────────
with open(CONFIG_SAVE_PATH, 'w') as f:
    # Clean up param names for readability
    clean_config = {}
    for model_name, data in best_config.items():
        clean_params = {k.split('_', 1)[-1]: v for k, v in data['params'].items()}
        clean_config[model_name] = {'val_loss': data['val_loss'], 'params': clean_params}
    json.dump(clean_config, f, indent=2)

print(f'\nSaved best hyperparameters to: {CONFIG_SAVE_PATH}')
print('\nTo use these hyperparameters automatically in Colab (or locally), you can load them from this path in subsequent runs.')

# %%
print('\n✅ OPTUNA SEARCH COMPLETE')
print('Next step: either')
print('  (A) Scroll up to cell 7 and manually set HIDDEN/LSTM_LAYERS/etc. from best_config above,')
print('  (B) Run the cell below to automatically update cell 7 hyperparameters,')
print('  (C) Skip and run cell 9+ (Model Training) with current cell 7 settings.')

# %%
## 2c — Display & Use Best Hyperparameters

# Pretty-print best hyperparameters
print('\n' + '='*70)
print('RECOMMENDED HYPERPARAMETERS FOR COLAB RUN')
print('='*70)

for model_name in ['mlp', 'lstm', 'transformer']:
    print(f'\n### {model_name.upper()} ###')
    print(f"Val Loss: {best_config[model_name]['val_loss']:.6f}")
    print('Parameters:')
    for k, v in best_config[model_name]['params'].items():
        print(f'  {k}: {v}')

print('\n' + '='*70)
print('Copy these values into Colab NB03 cell 7 (hyperparameters section)')
print('='*70)

# %% [markdown]
# ## 3 — Model Definitions
#
# Three models in increasing representational capacity:
# 1. **MLP** — flattens the 90-step window, no temporal structure (ablation baseline)
# 2. **LSTM** — bidirectional recurrent encoder (learns sequential dynamics)
# 3. **Transformer** — self-attention encoder (learns long-range patterns)
#
# The MLP establishes whether temporal structure is actually needed. If LSTM/Transformer only marginally beat MLP, the task may not require sequence modeling.
#
# ### 3a — MLP (Flat Baseline)

# %%
class MLPOrbit(nn.Module):
    """
    Flat MLP — no temporal structure.
    Input: (B, T, F) flattened to (B, T*F).
    Ablation baseline to test whether sequence modeling adds value.
    """
    def __init__(self, input_len, n_features, hidden, n_out, dropout):
        super().__init__()
        in_dim = input_len * n_features
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden * 2),
            nn.LayerNorm(hidden * 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden * 2, hidden),
            nn.LayerNorm(hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, n_out),
        )

    def forward(self, x):
        # x: (B, T, F) → flatten → (B, T*F)
        return self.net(x.flatten(start_dim=1))

mlp_model = MLPOrbit(INPUT_LEN, N_FEATURES, HIDDEN, N_OUT, DROPOUT).to(DEVICE)
n_params_mlp = sum(p.numel() for p in mlp_model.parameters() if p.requires_grad)
print(f'MLP parameters: {n_params_mlp:,}')

# %% [markdown]
# ### 3b — LSTM Model
#
# Bidirectional LSTM encoder → flatten last hidden state → two-layer FC head → 12 outputs.

# %%
class LSTMOrbit(nn.Module):
    def __init__(self, n_features, hidden, lstm_layers, n_out, dropout):
        super().__init__()
        self.lstm = nn.LSTM(n_features, hidden, lstm_layers,
                            batch_first=True, bidirectional=True,
                            dropout=dropout if lstm_layers > 1 else 0)
        # Explicit dropout on the final hidden state (needed when lstm_layers=1
        # because PyTorch disables internal LSTM dropout for single-layer models)
        self.hidden_dropout = nn.Dropout(dropout)
        fc_in = hidden * 2
        self.head = nn.Sequential(
            nn.LayerNorm(fc_in),
            nn.Linear(fc_in, fc_in // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(fc_in // 2, n_out),
        )

    def forward(self, x):
        _, (h, _) = self.lstm(x)
        # Concatenate final forward and backward hidden states, then apply dropout
        return self.head(self.hidden_dropout(torch.cat([h[-2], h[-1]], dim=-1)))

lstm_model = LSTMOrbit(N_FEATURES, HIDDEN, LSTM_LAYERS, N_OUT, DROPOUT).to(DEVICE)
n_params_lstm = sum(p.numel() for p in lstm_model.parameters() if p.requires_grad)
print(f'LSTM parameters: {n_params_lstm:,}')

# %% [markdown]
# ### 3b — Transformer Model
#
# Sinusoidal positional encoding → `nn.TransformerEncoder` → mean-pool sequence → two-layer FC head → 12 outputs.

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=500, dropout=0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(max_len).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div[:d_model // 2])
        self.register_buffer('pe', pe.unsqueeze(0))  # (1, max_len, d_model)

    def forward(self, x):
        return self.dropout(x + self.pe[:, :x.size(1)])


class TransformerOrbit(nn.Module):
    def __init__(self, n_features, d_model, nhead, num_encoder_layers, ff_dim, n_out, dropout):
        super().__init__()
        self.input_proj = nn.Linear(n_features, d_model)
        self.pos_enc    = PositionalEncoding(d_model, dropout=dropout)
        enc_layer = nn.TransformerEncoderLayer(d_model, nhead, ff_dim,
                                               dropout=dropout, batch_first=True,
                                               norm_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_encoder_layers)
        self.head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, n_out),
        )

    def forward(self, x):
        x = self.pos_enc(self.input_proj(x))
        x = self.encoder(x)
        ctx = x.mean(dim=1)   # mean-pool over sequence
        return self.head(ctx)

tf_model = TransformerOrbit(N_FEATURES, HIDDEN, TF_HEADS, TF_ENC_LAYERS, TF_FF_DIM, N_OUT, DROPOUT).to(DEVICE)
n_params_tf = sum(p.numel() for p in tf_model.parameters() if p.requires_grad)
print(f'Transformer parameters: {n_params_tf:,}')

# %% [markdown]
# ## 4 — Training Loop
#
# Shared training loop used for both models.
# Optimiser: **AdamW** | LR schedule: **cosine annealing** | Early stopping on validation loss.

# %%
def train_model(model, train_dl, val_dl, epochs, lr, patience, name):
    criterion = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=lr/100)

    best_val   = float('inf')
    best_state = deepcopy(model.state_dict())   # fallback: never None
    wait       = 0
    history    = {'train': [], 'val': []}

    for epoch in range(1, epochs + 1):
        # --- Train ---
        model.train()
        running = 0.0
        for Xb, yb in train_dl:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(Xb), yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            running += loss.item() * len(Xb)
        scheduler.step()
        train_loss = running / len(train_dl.dataset)

        # --- Validate ---
        model.eval()
        running = 0.0
        with torch.no_grad():
            for Xb, yb in val_dl:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                running += criterion(model(Xb), yb).item() * len(Xb)
        val_loss = running / len(val_dl.dataset)

        history['train'].append(train_loss)
        history['val'].append(val_loss)

        if epoch % 10 == 0 or epoch == 1:
            print(f'[{name}] Epoch {epoch:3d}/{epochs}  train={train_loss:.4f}  val={val_loss:.4f}  lr={scheduler.get_last_lr()[0]:.2e}')

        # Early stopping
        if val_loss < best_val:
            best_val   = val_loss
            best_state = deepcopy(model.state_dict())
            wait       = 0
        else:
            wait += 1
            if wait >= patience:
                print(f'  [{name}] Early stopping at epoch {epoch}')
                break

    model.load_state_dict(best_state)
    print(f'[{name}] Best val loss: {best_val:.4f}')
    return history

# %%
print('=== Training MLP (ablation baseline) ===')
mlp_history = train_model(mlp_model, train_dl, val_dl, EPOCHS, LR, PATIENCE, 'MLP')

print('\n=== Training LSTM ===')
lstm_history = train_model(lstm_model, train_dl, val_dl, EPOCHS, LR, PATIENCE, 'LSTM')

print('\n=== Training Transformer ===')
tf_history = train_model(tf_model, train_dl, val_dl, EPOCHS, LR, PATIENCE, 'Transformer')

# %% [markdown]
# ## 5 — Loss Curves

# %%
def plot_history(histories: dict, title: str):
    """Plot train/val loss curves for one or more models."""
    fig = go.Figure()
    colours = ['royalblue', 'firebrick', 'orange', 'green']
    for (name, hist), colour in zip(histories.items(), colours):
        epochs = list(range(1, len(hist['train']) + 1))
        fig.add_trace(go.Scatter(x=epochs, y=hist['train'], name=f'{name} train',
                                 line=dict(color=colour)))
        fig.add_trace(go.Scatter(x=epochs, y=hist['val'], name=f'{name} val',
                                 line=dict(color=colour, dash='dot')))
    fig.update_layout(title=title, xaxis_title='Epoch', yaxis_title='MSE Loss',
                      template='plotly_white')
    fig.show()

plot_history({'MLP': mlp_history, 'LSTM': lstm_history, 'Transformer': tf_history},
             'Train vs Validation Loss — All Models')

# %% [markdown]
# ## 6 — Save Weights & Download (Colab)

# %%
mlp_path  = DATA_DIR / 'mlp_orbit.pt'
lstm_path = DATA_DIR / 'lstm_orbit.pt'
tf_path   = DATA_DIR / 'transformer_orbit.pt'

torch.save({'model_state': mlp_model.state_dict(),
            'hparams': {'input_len': INPUT_LEN, 'n_features': N_FEATURES,
                        'hidden': HIDDEN, 'n_out': N_OUT, 'dropout': DROPOUT}},
           mlp_path)

torch.save({'model_state': lstm_model.state_dict(),
            'hparams': {'hidden': HIDDEN, 'lstm_layers': LSTM_LAYERS,
                        'n_features': N_FEATURES, 'n_out': N_OUT, 'dropout': DROPOUT}},
           lstm_path)

torch.save({'model_state': tf_model.state_dict(),
            'hparams': {'d_model': HIDDEN, 'nhead': TF_HEADS,
                        'num_encoder_layers': TF_ENC_LAYERS, 'ff_dim': TF_FF_DIM,
                        'n_features': N_FEATURES, 'n_out': N_OUT, 'dropout': DROPOUT}},
           tf_path)

for p in [mlp_path, lstm_path, tf_path]:
    print(f'Saved: {p.name}  ({p.stat().st_size/1024:.1f} KB)')

if IN_COLAB:
    from google.colab import files as _colab_files
    for p in [mlp_path, lstm_path, tf_path]:
        _colab_files.download(str(p))
    print('Downloads started — you will need all three .pt files in Notebook 04.')
